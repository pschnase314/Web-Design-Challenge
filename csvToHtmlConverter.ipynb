# %%
import pandas as pd

# %%
df = pd.read_csv("Resources/weather_data.csv")
df.head()
# Out:
#            City  Latitude  Longitude  Temperature (F)  Humidity  Wind Speed  \
# 0       ushuaia  -54.8000   -68.3000            41.23        92        6.02
# 1  kruisfontein  -34.0033    24.7314            48.18        75        3.96
# 2       itarema   -2.9248   -39.9167            82.81        65       19.80
# 3           sur   22.5667    59.5289            89.37        60        5.37
# 4      oussouye   12.4850   -16.5469            79.59        83       10.51
#
#    Cloud Coverage
# 0             100
# 1               1
# 2              22
# 3              19
# 4             100

# %%
output = df.to_html()

# %%
print(output)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Temperature (F)</th>
#       <th>Humidity</th>
#       <th>Wind Speed</th>
#       <th>Cloud Coverage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ushuaia</td>
#       <td>-54.8000</td>
#       <td>-68.3000</td>
#       <td>41.23</td>
#       <td>92</td>
#       <td>6.02</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>kruisfontein</td>
#       <td>-34.0033</td>
#       <td>24.7314</td>
#       <td>48.18</td>
#       <td>75</td>
#       <td>3.96</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>itarema</td>
#       <td>-2.9248</td>
#       <td>-39.9167</td>
#       <td>82.81</td>
#       <td>65</td>
#       <td>19.80</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...
